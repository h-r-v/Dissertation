# %%
# !pip install monai==1.3.2
# Out:
# Collecting monai==1.3.2
#   Downloading monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai==1.3.2) (2.1.2)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from monai==1.3.2) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai==1.3.2) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai==1.3.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai==1.3.2) (1.3.0)
# Downloading monai-1.3.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.2 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.3.2

# %%
import os
import tempfile
import glob
import random
import numpy as np
import gc
import uuid
import pickle
import time
import re

import nibabel as nib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from sklearn.model_selection import train_test_split

from monai.utils import set_determinism, first
from monai.data import DataLoader, Dataset, CacheDataset, decollate_batch
from monai.transforms import *
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference

import torch.nn.functional as F
import torch
# Out:
# 2024-08-18 21:34:09.643516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-18 21:34:09.643627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-18 21:34:09.786465: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Init

# %%
set_determinism(seed=0)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
limited = False

num_labels = 3

# %%
data_dir = '/kaggle/input/liver-segmentation-dataset/Task03_Liver'
# data_dir = 'Task03_Liver'
data_file_extension = "*.nii"
# data_file_extension = "*.nii.gz"

# %%
sample_id = 0

# %% [markdown]
# # Train, Val and Test paths

# %%
sample_dict = [{"image": glob.glob(os.path.join(data_dir, "imagesTr", data_file_extension))[sample_id], "label": glob.glob(os.path.join(data_dir, "labelsTr", data_file_extension))[sample_id], "meta_data": {"image_path":glob.glob(os.path.join(data_dir, "imagesTr", data_file_extension))[sample_id], "label_path":glob.glob(os.path.join(data_dir, "labelsTr", data_file_extension))[sample_id],}}]
if limited:
    train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", data_file_extension)))[:5]
    train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", data_file_extension)))[:5]
else:
    train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", data_file_extension)))
    train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", data_file_extension)))
data_dict = [{"image": image_name, "label": label_name, "meta_data": {"image_path":image_name, "label_path":label_name,}} for image_name, label_name in zip(train_images, train_labels)]

# %%
if limited:
    train_dict, val_dict = train_test_split(data_dict, test_size=0.4, random_state=42)
    val_dict, test_dict = train_test_split(val_dict, test_size=0.01, random_state=42)
else:
    train_dict, val_dict = train_test_split(data_dict, test_size=0.3, random_state=42)
    val_dict, test_dict = train_test_split(val_dict, test_size=0.4, random_state=42)

# %%
print(len(train_dict), len(val_dict), len(test_dict))
# Out:
# 91 24 16

# %% [markdown]
# # Augmenting and Preprocessing

# %%
class MapValues(MapTransform):
    def __init__(self, keys, from_value=None, to_value=None, allow_missing_keys=False):
        super().__init__(keys, allow_missing_keys)
        self.from_value = from_value
        self.to_value = to_value
    
    def __call__(self, data):
        if self.from_value==None or self.to_value==None:
            return d
        d = dict(data)
        for key in self.keys:
            if key in d:
                d[key] = np.where(d[key] == self.from_value, self.to_value, d[key])
        return d

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-70, #Check range
            a_max=120,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2), mode=("bilinear", "nearest")),
        SpatialPadd(keys=["image", "label"], spatial_size=(128, 128, 128)),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(128, 128, 128),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        RandShiftIntensityd(keys="image", offsets=0.1, prob=0.5),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-70, #Check range
            a_max=120,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2), mode=("bilinear", "nearest")),
        SpatialPadd(keys=["image", "label"], spatial_size=(128, 128, 128)),
    ]
)
# Out:
# /opt/conda/lib/python3.10/site-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)

# %% [markdown]
# ## Sanity check

# %%
def show_plane(ax, plane, cmap="gray", title=None, mask=True):
    if not mask: 
        ax.imshow(plane, cmap=cmap)
    else:
        colors = ["black", "green", "red"]
        cmap = ListedColormap(colors)
        boundaries = [-0.5, 0.5, 1.5, 2.5]
        norm = BoundaryNorm(boundaries, cmap.N, clip=True)
        ax.imshow(plane.astype(float), cmap=cmap, norm=norm, interpolation='nearest')
        
    ax.axis("off")
    if title:
        ax.set_title(title)

# %%
# check_ds = Dataset(data=sample_dict, transform=train_transforms)
# check_loader = DataLoader(check_ds, batch_size=1)
# check_data = first(check_loader)

# print(check_data['meta_data'])

# print(check_data['image'].shape)
# print(check_data['label'].shape)

# image, label = (check_data["image"].cpu().numpy()[0][0], check_data["label"].cpu().numpy()[0][0])
# print(f"image shape: {image.shape}, label shape: {label.shape}")

# _, (a, b) = plt.subplots(ncols=2, figsize=(15, 5))

# t = 0

# show_plane(a, image[:, :, t], title=f'Image')
# show_plane(b, label[:, :, t], title=f'Mask', cmap=None)

# %% [markdown]
# # Data Sets and Data loaders

# %%
train_ds = CacheDataset(data=train_dict, transform=train_transforms, cache_rate=1.0, num_workers=4)
val_ds = CacheDataset(data=val_dict, transform=val_transforms, cache_rate=1.0, num_workers=4)
# Out:
# Loading dataset: 100%|██████████| 91/91 [07:29<00:00,  4.94s/it]
# Loading dataset: 100%|██████████| 24/24 [02:11<00:00,  5.46s/it]

# %%
train_loader = DataLoader(train_ds, batch_size=1, num_workers=4)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)

# %% [markdown]
# # Train

# %%
def get_recent_checkpoint(dir_path, idx=0, ):
    paths = glob.glob(dir_path+'/*')
    
    if len(paths)==0:
        print('UUID not found')
        return None, None
    
    a = []
    for path in paths:
        data_file = path.split('/')[-1]
        epoch = re.findall(r'\d+', data_file)
        a.append(int(epoch[0]))
   
    if len(a)>0:
        recent_epoch = sorted(a, reverse=True)[idx]
    else:
        return None, None
   
    return recent_epoch, f'{dir_path}/data_{recent_epoch}.pkl'

# %% [markdown]
# ## Model, loss, optimizer, metrics and checkpoint

# %%
print('Using device:', device)

# Loss function
loss_function = DiceLoss(to_onehot_y=True, softmax=True)

# Metric
dice_metric = DiceMetric( reduction="mean")#include_background=False,

# Config
config = {
    'run_id': str(uuid.uuid4()),
    'current_epoch': 0,
    'max_epochs': 2 if limited else 200,
    'lr': 10**-4,
    'depth': 5,
    'strides': (2, 2, 2, 2),
    'channels': (16, 32, 64, 128, 256),
    'out_channels': num_labels,
    'norm': 'Norm.BATCH',
    }
    
#Utils
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=num_labels)])
post_label = Compose([AsDiscrete(to_onehot=num_labels)])

#Setting
if limited:
    verbose = True
    config['test_interval']=1
else:
    verbose = False
    config['test_interval']=4
# Out:
# Using device: cuda

# %%
idx, checkpoint_path = get_recent_checkpoint(dir_path='/kaggle/input/tl-pan/ea9d559e-2a15-4001-abf9-b9bd28f43c7d', idx=0)

print("No checkpoint found" if checkpoint_path == None else "Checkpoint found")
print(idx, checkpoint_path)

checkpoint_data = None

if checkpoint_path!=None:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     with open(checkpoint_path, 'rb') as fp:
#         best_checkpoint_data = pickle.load(fp)

    best_checkpoint_data = torch.load(checkpoint_path, map_location=device)

    config = best_checkpoint_data['config']
    
    exclude_list = ['config', 'net_state_dict', 'optimizer_state_dict']
    
    checkpoint_data = {}
    
    for i in best_checkpoint_data.keys():
        if i not in exclude_list:
            checkpoint_data[i] = best_checkpoint_data[i]
            
    config['current_epoch']+=1
# Out:
# UUID not found
# No checkpoint found
# None None

# %%
# Model
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=config['out_channels'],
    channels=config['channels'],
    strides=config['strides'],
    num_res_units=config['depth']-1,
    norm=Norm.BATCH,
    ).to(device)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), config['lr'])

if checkpoint_path!=None:
    model.load_state_dict(best_checkpoint_data["net_state_dict"])
    optimizer.load_state_dict(best_checkpoint_data["optimizer_state_dict"])

# %%
def train(model, config, optimizer, loss_function, dice_metric, post_pred, post_label, verbose, checkpoint_data=None):
    
    best_score = -100000 if checkpoint_data==None else checkpoint_data['best_score']
    best_config = {} if checkpoint_data==None else checkpoint_data['best_config']

    per_epoch_loss = [] if checkpoint_data==None else checkpoint_data['per_epoch_loss']
    per_epoch_vloss = [] if checkpoint_data==None else checkpoint_data['per_epoch_vloss']
    metrics = [] if checkpoint_data==None else checkpoint_data['metrics']
    train_epoch_times = [] if checkpoint_data==None else checkpoint_data['train_epoch_times']
    full_epoch_times = [] if checkpoint_data==None else checkpoint_data['full_epoch_times']
    
    max_epochs = config['max_epochs']
    
    save_history = [] if checkpoint_data==None else checkpoint_data['save_history']
    
    for epoch in range(config['current_epoch'], max_epochs):
        
        print("-" * 25)
        print(f"epoch {epoch + 1}/{max_epochs}")

        train_epoch_start_time = time.time()
        full_epoch_start_time = time.time()

        model.train()

        train_epoch_loss = 0

        config['current_epoch'] = epoch
        
        for idx_data, data in enumerate(train_loader):
            inputs = data["image"].to(device)
            labels = data["label"].to(device)

            optimizer.zero_grad()

            outputs = model(inputs)

            loss = loss_function(outputs, labels) 
            loss.backward()

            optimizer.step()

            train_epoch_loss += loss.item()
            if verbose:    
                print(f"Batch {idx_data+1}/{len(train_ds)}, " f"train_loss: {loss.item():.4f}")

        train_epoch_times.append(train_epoch_start_time-time.time())

        train_epoch_loss /= len(train_ds)
        per_epoch_loss.append(train_epoch_loss)
        print("-" * 10)
        print(f"Train epoch {epoch + 1} loss: {train_epoch_loss:.4f}")

        if epoch%config['test_interval']==0:

            model.eval()

            if verbose:
                print("-" * 15)

            val_epoch_loss = 0

            with torch.no_grad():
                for idx_data,data in enumerate(val_loader):
                    inputs = data["image"].to(device)
                    labels = data["label"].to(device)

                    roi_size = (128, 128, 128)
                    sw_batch_size = 4
                    
                    outputs = sliding_window_inference(inputs, roi_size, sw_batch_size, model, overlap=0, mode='constant')

                    loss = loss_function(outputs, labels)
                    val_epoch_loss += loss.item()
                    val_outputs = [post_pred(i) for i in decollate_batch(outputs)]
                    val_labels = [post_label(i) for i in decollate_batch(labels)]
                    dice_metric(y_pred=val_outputs, y=val_labels)
                    if verbose: 
                        print(f"Batch {idx_data+1}/{len(val_ds) // val_loader.batch_size}, " f"val_loss: {loss.item():.4f}")

                metric = dice_metric.aggregate().item()
                dice_metric.reset()

            val_epoch_loss /= len(val_loader)
            per_epoch_vloss.append(val_epoch_loss)

            if verbose:
                print("-" * 10)

            print(f"Val epoch {epoch + 1} loss: {val_epoch_loss:.4f}")

            if verbose:
                print("-" * 20)

            metrics.append(metric)
            print("Dice Loss: ", metric)

            if metric>=best_score:
                best_config = config
                best_score = metric
                checkpoint_data = {
                'config':config, 
                'per_epoch_loss': per_epoch_loss,
                'per_epoch_vloss': per_epoch_vloss,
                'metrics':metrics,
                "net_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                'train_epoch_times': train_epoch_times,
                'full_epoch_times': full_epoch_times,
                'best_config': best_config,
                'best_score': best_score,
                'save_history': save_history,
                }
                if not os.path.exists(os.path.join('/kaggle/working/',str(config['run_id']))):
                    os.mkdir(os.path.join('/kaggle/working/',str(config['run_id'])))
#                 with open(os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')), 'wb') as fp:
#                     pickle.dump(checkpoint_data, fp)
                file_path = os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl'))
                torch.save(checkpoint_data, file_path)
                
                print(f"Checkpoint created: ({os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl'))})")
                
                if os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')) not in save_history:
                    save_history.append(os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')))
                if len(save_history)>3:
                    for i in save_history[:-3]:
                        if os.path.exists(i):
                            os.remove(i)

        full_epoch_times.append(full_epoch_start_time-time.time())

    checkpoint_data = {
        'config':config, 
        'per_epoch_loss': per_epoch_loss,
        'per_epoch_vloss': per_epoch_vloss,
        'metrics':metrics,
        "net_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        'train_epoch_times': train_epoch_times,
        'full_epoch_times': full_epoch_times,
        'best_config': best_config,
        'best_score': best_score,
        'save_history': save_history,
    }
    
    if os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')) not in save_history:
        save_history.append(os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')))
    
    if not os.path.exists(os.path.join('/kaggle/working/',str(config['run_id']))):
        os.mkdir(os.path.join('/kaggle/working/',str(config['run_id'])))
#     with open(os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl')), 'wb') as fp:
#         pickle.dump(checkpoint_data, fp)
    file_path = os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl'))
    torch.save(checkpoint_data, file_path)
    print(f"Checkpoint created: ({os.path.join('/kaggle/working/',os.path.join(config['run_id'], f'data_{epoch}.pkl'))})")

    print('-'*50)
    print('Run complete.')
    print('-'*50)
    
    return best_config

# %%
best_config = train(model, config, optimizer, loss_function, dice_metric, post_pred, post_label, verbose, checkpoint_data)
# Out:
# -------------------------
# epoch 1/200
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ----------
# Train epoch 1 loss: 0.7071
# Val epoch 1 loss: 0.7118
# Dice Loss:  0.4501045048236847
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_0.pkl)
# -------------------------
# epoch 2/200
# ----------
# Train epoch 2 loss: 0.6452
# -------------------------
# epoch 3/200
# ----------
# Train epoch 3 loss: 0.6082
# -------------------------
# epoch 4/200
# ----------
# Train epoch 4 loss: 0.5859
# -------------------------
# epoch 5/200
# ----------
# Train epoch 5 loss: 0.5485
# Val epoch 5 loss: 0.6210
# Dice Loss:  0.5654471516609192
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_4.pkl)
# -------------------------
# epoch 6/200
# ----------
# Train epoch 6 loss: 0.5432
# -------------------------
# epoch 7/200
# ----------
# Train epoch 7 loss: 0.5250
# -------------------------
# epoch 8/200
# ----------
# Train epoch 8 loss: 0.4918
# -------------------------
# epoch 9/200
# ----------
# Train epoch 9 loss: 0.4767
# Val epoch 9 loss: 0.5096
# Dice Loss:  0.6509197354316711
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_8.pkl)
# -------------------------
# epoch 10/200
# ----------
# Train epoch 10 loss: 0.4636
# -------------------------
# epoch 11/200
# ----------
# Train epoch 11 loss: 0.4490
# -------------------------
# epoch 12/200
# ----------
# Train epoch 12 loss: 0.4455
# -------------------------
# epoch 13/200
# ----------
# Train epoch 13 loss: 0.4302
# Val epoch 13 loss: 0.5338
# Dice Loss:  0.5722500681877136
# -------------------------
# epoch 14/200
# ----------
# Train epoch 14 loss: 0.4153
# -------------------------
# epoch 15/200
# ----------
# Train epoch 15 loss: 0.4320
# -------------------------
# epoch 16/200
# ----------
# Train epoch 16 loss: 0.4003
# -------------------------
# epoch 17/200
# ----------
# Train epoch 17 loss: 0.4132
# Val epoch 17 loss: 0.3757
# Dice Loss:  0.7131319046020508
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_16.pkl)
# -------------------------
# epoch 18/200
# ----------
# Train epoch 18 loss: 0.3957
# -------------------------
# epoch 19/200
# ----------
# Train epoch 19 loss: 0.3891
# -------------------------
# epoch 20/200
# ----------
# Train epoch 20 loss: 0.3758
# -------------------------
# epoch 21/200
# ----------
# Train epoch 21 loss: 0.3660
# Val epoch 21 loss: 0.3463
# Dice Loss:  0.7402667999267578
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_20.pkl)
# -------------------------
# epoch 22/200
# ----------
# Train epoch 22 loss: 0.3657
# -------------------------
# epoch 23/200
# ----------
# Train epoch 23 loss: 0.3759
# -------------------------
# epoch 24/200
# ----------
# Train epoch 24 loss: 0.3638
# -------------------------
# epoch 25/200
# ----------
# Train epoch 25 loss: 0.3370
# Val epoch 25 loss: 0.3277
# Dice Loss:  0.7247902750968933
# -------------------------
# epoch 26/200
# ----------
# Train epoch 26 loss: 0.3651
# -------------------------
# epoch 27/200
# ----------
# Train epoch 27 loss: 0.3459
# -------------------------
# epoch 28/200
# ----------
# Train epoch 28 loss: 0.3463
# -------------------------
# epoch 29/200
# ----------
# Train epoch 29 loss: 0.3496
# Val epoch 29 loss: 0.3054
# Dice Loss:  0.7703025341033936
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_28.pkl)
# -------------------------
# epoch 30/200
# ----------
# Train epoch 30 loss: 0.3405
# -------------------------
# epoch 31/200
# ----------
# Train epoch 31 loss: 0.3416
# -------------------------
# epoch 32/200
# ----------
# Train epoch 32 loss: 0.3483
# -------------------------
# epoch 33/200
# ----------
# Train epoch 33 loss: 0.3313
# Val epoch 33 loss: 0.2822
# Dice Loss:  0.7759592533111572
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_32.pkl)
# -------------------------
# epoch 34/200
# ----------
# Train epoch 34 loss: 0.3268
# -------------------------
# epoch 35/200
# ----------
# Train epoch 35 loss: 0.3179
# -------------------------
# epoch 36/200
# ----------
# Train epoch 36 loss: 0.3368
# -------------------------
# epoch 37/200
# ----------
# Train epoch 37 loss: 0.3131
# Val epoch 37 loss: 0.2876
# Dice Loss:  0.765893280506134
# -------------------------
# epoch 38/200
# ----------
# Train epoch 38 loss: 0.3172
# -------------------------
# epoch 39/200
# ----------
# Train epoch 39 loss: 0.3223
# -------------------------
# epoch 40/200
# ----------
# Train epoch 40 loss: 0.3203
# -------------------------
# epoch 41/200
# ----------
# Train epoch 41 loss: 0.3102
# Val epoch 41 loss: 0.2621
# Dice Loss:  0.7891030311584473
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_40.pkl)
# -------------------------
# epoch 42/200
# ----------
# Train epoch 42 loss: 0.3310
# -------------------------
# epoch 43/200
# ----------
# Train epoch 43 loss: 0.3093
# -------------------------
# epoch 44/200
# ----------
# Train epoch 44 loss: 0.3179
# -------------------------
# epoch 45/200
# ----------
# Train epoch 45 loss: 0.3031
# Val epoch 45 loss: 0.2613
# Dice Loss:  0.7898030877113342
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_44.pkl)
# -------------------------
# epoch 46/200
# ----------
# Train epoch 46 loss: 0.3141
# -------------------------
# epoch 47/200
# ----------
# Train epoch 47 loss: 0.3036
# -------------------------
# epoch 48/200
# ----------
# Train epoch 48 loss: 0.3105
# -------------------------
# epoch 49/200
# ----------
# Train epoch 49 loss: 0.3043
# Val epoch 49 loss: 0.2917
# Dice Loss:  0.7547881007194519
# -------------------------
# epoch 50/200
# ----------
# Train epoch 50 loss: 0.3124
# -------------------------
# epoch 51/200
# ----------
# Train epoch 51 loss: 0.3199
# -------------------------
# epoch 52/200
# ----------
# Train epoch 52 loss: 0.2966
# -------------------------
# epoch 53/200
# ----------
# Train epoch 53 loss: 0.2972
# Val epoch 53 loss: 0.2738
# Dice Loss:  0.7726330757141113
# -------------------------
# epoch 54/200
# ----------
# Train epoch 54 loss: 0.2793
# -------------------------
# epoch 55/200
# ----------
# Train epoch 55 loss: 0.3115
# -------------------------
# epoch 56/200
# ----------
# Train epoch 56 loss: 0.2791
# -------------------------
# epoch 57/200
# ----------
# Train epoch 57 loss: 0.2924
# Val epoch 57 loss: 0.2645
# Dice Loss:  0.7807443737983704
# -------------------------
# epoch 58/200
# ----------
# Train epoch 58 loss: 0.2977
# -------------------------
# epoch 59/200
# ----------
# Train epoch 59 loss: 0.2687
# -------------------------
# epoch 60/200
# ----------
# Train epoch 60 loss: 0.2887
# -------------------------
# epoch 61/200
# ----------
# Train epoch 61 loss: 0.3078
# Val epoch 61 loss: 0.2517
# Dice Loss:  0.7913327813148499
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_60.pkl)
# -------------------------
# epoch 62/200
# ----------
# Train epoch 62 loss: 0.2972
# -------------------------
# epoch 63/200
# ----------
# Train epoch 63 loss: 0.2828
# -------------------------
# epoch 64/200
# ----------
# Train epoch 64 loss: 0.2918
# -------------------------
# epoch 65/200
# ----------
# Train epoch 65 loss: 0.2939
# Val epoch 65 loss: 0.2358
# Dice Loss:  0.8085234761238098
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_64.pkl)
# -------------------------
# epoch 66/200
# ----------
# Train epoch 66 loss: 0.2776
# -------------------------
# epoch 67/200
# ----------
# Train epoch 67 loss: 0.2964
# -------------------------
# epoch 68/200
# ----------
# Train epoch 68 loss: 0.2830
# -------------------------
# epoch 69/200
# ----------
# Train epoch 69 loss: 0.2674
# Val epoch 69 loss: 0.2305
# Dice Loss:  0.8146947026252747
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_68.pkl)
# -------------------------
# epoch 70/200
# ----------
# Train epoch 70 loss: 0.3081
# -------------------------
# epoch 71/200
# ----------
# Train epoch 71 loss: 0.2858
# -------------------------
# epoch 72/200
# ----------
# Train epoch 72 loss: 0.2768
# -------------------------
# epoch 73/200
# ----------
# Train epoch 73 loss: 0.2813
# Val epoch 73 loss: 0.2308
# Dice Loss:  0.8125674724578857
# -------------------------
# epoch 74/200
# ----------
# Train epoch 74 loss: 0.2920
# -------------------------
# epoch 75/200
# ----------
# Train epoch 75 loss: 0.2772
# -------------------------
# epoch 76/200
# ----------
# Train epoch 76 loss: 0.2894
# -------------------------
# epoch 77/200
# ----------
# Train epoch 77 loss: 0.2964
# Val epoch 77 loss: 0.2603
# Dice Loss:  0.7825878262519836
# -------------------------
# epoch 78/200
# ----------
# Train epoch 78 loss: 0.2770
# -------------------------
# epoch 79/200
# ----------
# Train epoch 79 loss: 0.2840
# -------------------------
# epoch 80/200
# ----------
# Train epoch 80 loss: 0.3049
# -------------------------
# epoch 81/200
# ----------
# Train epoch 81 loss: 0.2819
# Val epoch 81 loss: 0.2302
# Dice Loss:  0.8131757378578186
# -------------------------
# epoch 82/200
# ----------
# Train epoch 82 loss: 0.2845
# -------------------------
# epoch 83/200
# ----------
# Train epoch 83 loss: 0.2641
# -------------------------
# epoch 84/200
# ----------
# Train epoch 84 loss: 0.2931
# -------------------------
# epoch 85/200
# ----------
# Train epoch 85 loss: 0.2961
# Val epoch 85 loss: 0.2883
# Dice Loss:  0.7537563443183899
# -------------------------
# epoch 86/200
# ----------
# Train epoch 86 loss: 0.2853
# -------------------------
# epoch 87/200
# ----------
# Train epoch 87 loss: 0.2806
# -------------------------
# epoch 88/200
# ----------
# Train epoch 88 loss: 0.2806
# -------------------------
# epoch 89/200
# ----------
# Train epoch 89 loss: 0.2872
# Val epoch 89 loss: 0.2316
# Dice Loss:  0.8110087513923645
# -------------------------
# epoch 90/200
# ----------
# Train epoch 90 loss: 0.2887
# -------------------------
# epoch 91/200
# ----------
# Train epoch 91 loss: 0.2877
# -------------------------
# epoch 92/200
# ----------
# Train epoch 92 loss: 0.2794
# -------------------------
# epoch 93/200
# ----------
# Train epoch 93 loss: 0.2835
# Val epoch 93 loss: 0.2505
# Dice Loss:  0.7903693318367004
# -------------------------
# epoch 94/200
# ----------
# Train epoch 94 loss: 0.2834
# -------------------------
# epoch 95/200
# ----------
# Train epoch 95 loss: 0.2775
# -------------------------
# epoch 96/200
# ----------
# Train epoch 96 loss: 0.2678
# -------------------------
# epoch 97/200
# ----------
# Train epoch 97 loss: 0.2855
# Val epoch 97 loss: 0.2303
# Dice Loss:  0.8139521479606628
# -------------------------
# epoch 98/200
# ----------
# Train epoch 98 loss: 0.2634
# -------------------------
# epoch 99/200
# ----------
# Train epoch 99 loss: 0.2806
# -------------------------
# epoch 100/200
# ----------
# Train epoch 100 loss: 0.2727
# -------------------------
# epoch 101/200
# ----------
# Train epoch 101 loss: 0.2765
# Val epoch 101 loss: 0.2413
# Dice Loss:  0.8004121780395508
# -------------------------
# epoch 102/200
# ----------
# Train epoch 102 loss: 0.2789
# -------------------------
# epoch 103/200
# ----------
# Train epoch 103 loss: 0.2655
# -------------------------
# epoch 104/200
# ----------
# Train epoch 104 loss: 0.2724
# -------------------------
# epoch 105/200
# ----------
# Train epoch 105 loss: 0.2623
# Val epoch 105 loss: 0.2233
# Dice Loss:  0.8192300796508789
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_104.pkl)
# -------------------------
# epoch 106/200
# ----------
# Train epoch 106 loss: 0.2627
# -------------------------
# epoch 107/200
# ----------
# Train epoch 107 loss: 0.2713
# -------------------------
# epoch 108/200
# ----------
# Train epoch 108 loss: 0.2574
# -------------------------
# epoch 109/200
# ----------
# Train epoch 109 loss: 0.2426
# Val epoch 109 loss: 0.2264
# Dice Loss:  0.8162303566932678
# -------------------------
# epoch 110/200
# ----------
# Train epoch 110 loss: 0.2703
# -------------------------
# epoch 111/200
# ----------
# Train epoch 111 loss: 0.2661
# -------------------------
# epoch 112/200
# ----------
# Train epoch 112 loss: 0.2699
# -------------------------
# epoch 113/200
# ----------
# Train epoch 113 loss: 0.2802
# Val epoch 113 loss: 0.2393
# Dice Loss:  0.8023581504821777
# -------------------------
# epoch 114/200
# ----------
# Train epoch 114 loss: 0.2651
# -------------------------
# epoch 115/200
# ----------
# Train epoch 115 loss: 0.2845
# -------------------------
# epoch 116/200
# ----------
# Train epoch 116 loss: 0.2598
# -------------------------
# epoch 117/200
# ----------
# Train epoch 117 loss: 0.2580
# Val epoch 117 loss: 0.2255
# Dice Loss:  0.8164593577384949
# -------------------------
# epoch 118/200
# ----------
# Train epoch 118 loss: 0.2530
# -------------------------
# epoch 119/200
# ----------
# Train epoch 119 loss: 0.2845
# -------------------------
# epoch 120/200
# ----------
# Train epoch 120 loss: 0.2776
# -------------------------
# epoch 121/200
# ----------
# Train epoch 121 loss: 0.2758
# Val epoch 121 loss: 0.2165
# Dice Loss:  0.8252895474433899
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_120.pkl)
# -------------------------
# epoch 122/200
# ----------
# Train epoch 122 loss: 0.2660
# -------------------------
# epoch 123/200
# ----------
# Train epoch 123 loss: 0.2542
# -------------------------
# epoch 124/200
# ----------
# Train epoch 124 loss: 0.2715
# -------------------------
# epoch 125/200
# ----------
# Train epoch 125 loss: 0.2695
# Val epoch 125 loss: 0.2225
# Dice Loss:  0.8194368481636047
# -------------------------
# epoch 126/200
# ----------
# Train epoch 126 loss: 0.2788
# -------------------------
# epoch 127/200
# ----------
# Train epoch 127 loss: 0.2714
# -------------------------
# epoch 128/200
# ----------
# Train epoch 128 loss: 0.2524
# -------------------------
# epoch 129/200
# ----------
# Train epoch 129 loss: 0.2611
# Val epoch 129 loss: 0.2375
# Dice Loss:  0.8041685223579407
# -------------------------
# epoch 130/200
# ----------
# Train epoch 130 loss: 0.2647
# -------------------------
# epoch 131/200
# ----------
# Train epoch 131 loss: 0.2582
# -------------------------
# epoch 132/200
# ----------
# Train epoch 132 loss: 0.2939
# -------------------------
# epoch 133/200
# ----------
# Train epoch 133 loss: 0.2762
# Val epoch 133 loss: 0.2314
# Dice Loss:  0.8108671307563782
# -------------------------
# epoch 134/200
# ----------
# Train epoch 134 loss: 0.2622
# -------------------------
# epoch 135/200
# ----------
# Train epoch 135 loss: 0.2551
# -------------------------
# epoch 136/200
# ----------
# Train epoch 136 loss: 0.2667
# -------------------------
# epoch 137/200
# ----------
# Train epoch 137 loss: 0.2553
# Val epoch 137 loss: 0.2147
# Dice Loss:  0.8274254202842712
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_136.pkl)
# -------------------------
# epoch 138/200
# ----------
# Train epoch 138 loss: 0.2630
# -------------------------
# epoch 139/200
# ----------
# Train epoch 139 loss: 0.2574
# -------------------------
# epoch 140/200
# ----------
# Train epoch 140 loss: 0.2786
# -------------------------
# epoch 141/200
# ----------
# Train epoch 141 loss: 0.2798
# Val epoch 141 loss: 0.2108
# Dice Loss:  0.8303807377815247
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_140.pkl)
# -------------------------
# epoch 142/200
# ----------
# Train epoch 142 loss: 0.2659
# -------------------------
# epoch 143/200
# ----------
# Train epoch 143 loss: 0.2729
# -------------------------
# epoch 144/200
# ----------
# Train epoch 144 loss: 0.2561
# -------------------------
# epoch 145/200
# ----------
# Train epoch 145 loss: 0.2556
# Val epoch 145 loss: 0.2261
# Dice Loss:  0.8154682517051697
# -------------------------
# epoch 146/200
# ----------
# Train epoch 146 loss: 0.2844
# -------------------------
# epoch 147/200
# ----------
# Train epoch 147 loss: 0.2552
# -------------------------
# epoch 148/200
# ----------
# Train epoch 148 loss: 0.2504
# -------------------------
# epoch 149/200
# ----------
# Train epoch 149 loss: 0.2619
# Val epoch 149 loss: 0.2156
# Dice Loss:  0.8263580203056335
# -------------------------
# epoch 150/200
# ----------
# Train epoch 150 loss: 0.2711
# -------------------------
# epoch 151/200
# ----------
# Train epoch 151 loss: 0.2439
# -------------------------
# epoch 152/200
# ----------
# Train epoch 152 loss: 0.2434
# -------------------------
# epoch 153/200
# ----------
# Train epoch 153 loss: 0.2588
# Val epoch 153 loss: 0.2146
# Dice Loss:  0.8278020024299622
# -------------------------
# epoch 154/200
# ----------
# Train epoch 154 loss: 0.2565
# -------------------------
# epoch 155/200
# ----------
# Train epoch 155 loss: 0.2575
# -------------------------
# epoch 156/200
# ----------
# Train epoch 156 loss: 0.2639
# -------------------------
# epoch 157/200
# ----------
# Train epoch 157 loss: 0.2565
# Val epoch 157 loss: 0.2141
# Dice Loss:  0.8279743194580078
# -------------------------
# epoch 158/200
# ----------
# Train epoch 158 loss: 0.2553
# -------------------------
# epoch 159/200
# ----------
# Train epoch 159 loss: 0.2620
# -------------------------
# epoch 160/200
# ----------
# Train epoch 160 loss: 0.2582
# -------------------------
# epoch 161/200
# ----------
# Train epoch 161 loss: 0.2498
# Val epoch 161 loss: 0.2190
# Dice Loss:  0.8221331238746643
# -------------------------
# epoch 162/200
# ----------
# Train epoch 162 loss: 0.2499
# -------------------------
# epoch 163/200
# ----------
# Train epoch 163 loss: 0.2457
# -------------------------
# epoch 164/200
# ----------
# Train epoch 164 loss: 0.2595
# -------------------------
# epoch 165/200
# ----------
# Train epoch 165 loss: 0.2543
# Val epoch 165 loss: 0.2152
# Dice Loss:  0.8264765739440918
# -------------------------
# epoch 166/200
# ----------
# Train epoch 166 loss: 0.2419
# -------------------------
# epoch 167/200
# ----------
# Train epoch 167 loss: 0.2746
# -------------------------
# epoch 168/200
# ----------
# Train epoch 168 loss: 0.2605
# -------------------------
# epoch 169/200
# ----------
# Train epoch 169 loss: 0.2600
# Val epoch 169 loss: 0.2140
# Dice Loss:  0.8278276324272156
# -------------------------
# epoch 170/200
# ----------
# Train epoch 170 loss: 0.2650
# -------------------------
# epoch 171/200
# ----------
# Train epoch 171 loss: 0.2744
# -------------------------
# epoch 172/200
# ----------
# Train epoch 172 loss: 0.2583
# -------------------------
# epoch 173/200
# ----------
# Train epoch 173 loss: 0.2679
# Val epoch 173 loss: 0.2310
# Dice Loss:  0.810540497303009
# -------------------------
# epoch 174/200
# ----------
# Train epoch 174 loss: 0.2648
# -------------------------
# epoch 175/200
# ----------
# Train epoch 175 loss: 0.2513
# -------------------------
# epoch 176/200
# ----------
# Train epoch 176 loss: 0.2703
# -------------------------
# epoch 177/200
# ----------
# Train epoch 177 loss: 0.2476
# Val epoch 177 loss: 0.2139
# Dice Loss:  0.8283408284187317
# -------------------------
# epoch 178/200
# ----------
# Train epoch 178 loss: 0.2556
# -------------------------
# epoch 179/200
# ----------
# Train epoch 179 loss: 0.2546
# -------------------------
# epoch 180/200
# ----------
# Train epoch 180 loss: 0.2576
# -------------------------
# epoch 181/200
# ----------
# Train epoch 181 loss: 0.2383
# Val epoch 181 loss: 0.2046
# Dice Loss:  0.837428629398346
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_180.pkl)
# -------------------------
# epoch 182/200
# ----------
# Train epoch 182 loss: 0.2573
# -------------------------
# epoch 183/200
# ----------
# Train epoch 183 loss: 0.2848
# -------------------------
# epoch 184/200
# ----------
# Train epoch 184 loss: 0.2291
# -------------------------
# epoch 185/200
# ----------
# Train epoch 185 loss: 0.2820
# Val epoch 185 loss: 0.2246
# Dice Loss:  0.8171372413635254
# -------------------------
# epoch 186/200
# ----------
# Train epoch 186 loss: 0.2579
# -------------------------
# epoch 187/200
# ----------
# Train epoch 187 loss: 0.2502
# -------------------------
# epoch 188/200
# ----------
# Train epoch 188 loss: 0.2732
# -------------------------
# epoch 189/200
# ----------
# Train epoch 189 loss: 0.2493
# Val epoch 189 loss: 0.2178
# Dice Loss:  0.8237175345420837
# -------------------------
# epoch 190/200
# ----------
# Train epoch 190 loss: 0.2471
# -------------------------
# epoch 191/200
# ----------
# Train epoch 191 loss: 0.2455
# -------------------------
# epoch 192/200
# ----------
# Train epoch 192 loss: 0.2453
# -------------------------
# epoch 193/200
# ----------
# Train epoch 193 loss: 0.2399
# Val epoch 193 loss: 0.2194
# Dice Loss:  0.821995198726654
# -------------------------
# epoch 194/200
# ----------
# Train epoch 194 loss: 0.2683
# -------------------------
# epoch 195/200
# ----------
# Train epoch 195 loss: 0.2679
# -------------------------
# epoch 196/200
# ----------
# Train epoch 196 loss: 0.2554
# -------------------------
# epoch 197/200
# ----------
# Train epoch 197 loss: 0.2599
# Val epoch 197 loss: 0.2251
# Dice Loss:  0.8170974850654602
# -------------------------
# epoch 198/200
# ----------
# Train epoch 198 loss: 0.2556
# -------------------------
# epoch 199/200
# ----------
# Train epoch 199 loss: 0.2665
# -------------------------
# epoch 200/200
# ----------
# Train epoch 200 loss: 0.2428
# Checkpoint created: (/kaggle/working/6103f738-9d8a-481a-86e4-a02f5bd55862/data_199.pkl)
# --------------------------------------------------
# Run complete.
# --------------------------------------------------

# %% [markdown]
# # Evaluation

# %%
eval_ = False

# %%
if eval_ == True:
    run_id = config['run_id']
    start_epoch, checkpoint_path = get_recent_checkpoint(dir_path=f'/kaggle/input/parch-cp-1/{run_id}')
else:
    config = best_config
    run_id = config['run_id']
    start_epoch, checkpoint_path = get_recent_checkpoint(dir_path=f'/kaggle/working/{run_id}')

# with open(checkpoint_path, 'rb') as fp:
#     best_checkpoint_data = pickle.load(fp)
best_checkpoint_data = torch.load(checkpoint_path)

# %%
per_epoch_loss = best_checkpoint_data['per_epoch_loss']
per_epoch_vloss = best_checkpoint_data['per_epoch_vloss']
metrics = best_checkpoint_data['metrics']
train_epoch_times = best_checkpoint_data['train_epoch_times']
full_epoch_times = best_checkpoint_data['full_epoch_times']
test_interval = config['test_interval']

_, (a, b) = plt.subplots(ncols=2, figsize=(15, 5), sharex=True)

a.plot(list(range(1, len(per_epoch_loss)+1)), per_epoch_loss, label='Training Loss', color='c')
a.plot(list(range(1,len(per_epoch_vloss)*test_interval+1,test_interval)), per_epoch_vloss, label='Validation Loss', color='r')
a.set_title('Loss')
# a.xlabel('Epochs')
# a.ylabel('Loss')
a.legend()

b.plot(list(range(1,len(per_epoch_vloss)*test_interval+1,test_interval)), metrics, label='Validation Mean Dice', color='r')
b.set_title('Val Mean Dice')
# b.xlabel('Epochs')
# b.ylabel('Val Mean Dice')

_, (a, b) = plt.subplots(ncols=2, figsize=(15, 5), sharex=True)

a.plot(list(range(1, len(train_epoch_times)+1)), train_epoch_times, label='Train epoch times')
a.legend()

b.plot(list(range(1, len(full_epoch_times)+1)), full_epoch_times, label='Full_epoch_times')
b.legend()

# %%
# len(per_epoch_loss), len(per_epoch_vloss), len(metrics), len(train_epoch_times), len(full_epoch_times)

# %% [markdown]
# # Best model output viz

# %%
best_trained_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=config['out_channels'],
    channels=config['channels'],
    strides=config['strides'],
    num_res_units=config['depth']-1,
    norm=Norm.BATCH,
    ).to(device)

model.load_state_dict(best_checkpoint_data["net_state_dict"])
            
best_trained_model.eval()
print()

# %%
to_pred = Compose([AsDiscrete(argmax=True, to_onehot=None)])

# %%
plot_interval = 5

# %%
with torch.no_grad():
    for ix, data in enumerate(val_loader):
        roi_size = (128, 128, 128)
        sw_batch_size = 4
        
        outputs = sliding_window_inference(data["image"].to(device), roi_size, sw_batch_size, model, device="cpu", overlap=0, mode='constant')
        
        val_outputs = [post_pred(i) for i in decollate_batch(outputs)]
        val_labels = [post_label(i) for i in decollate_batch(data['label'])]
        dice_metric(y_pred=val_outputs, y=val_labels)
            
        if ix%plot_interval==0:
            prediction = [to_pred(i) for i in decollate_batch(outputs)]
        
            _, (a, b, c) = plt.subplots(ncols=3, figsize=(15, 5))

            t = outputs[0].shape[-1]//2
            show_plane(a, data["image"][0,0,:, :, t], title=f'Image {ix}', mask=False)
            show_plane(b, data["label"][0,0,:, :, t], title=f'Mask {ix}') 
            show_plane(c, prediction[0][0][:, :, t], title=f'Output {ix}') 

metric = dice_metric.aggregate()
dice_metric.reset()

print(metric)
# Out:
# tensor([0.6888])

# %%
np.unique(prediction[0].flatten())
# Out:
# array([0., 1., 2.], dtype=float32)
